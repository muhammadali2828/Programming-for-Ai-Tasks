# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   8693 non-null   object
#  1   HomePlanet    8492 non-null   object
#  2   CryoSleep     8476 non-null   object
#  3   Cabin         8494 non-null   object
#  4   Destination   8511 non-null   object
#  5   Age           8514 non-null   float64
#  6   VIP           8490 non-null   object
#  7   RoomService   8512 non-null   float64
#  8   FoodCourt     8510 non-null   float64
#  9   ShoppingMall  8485 non-null   float64
#  10  Spa           8510 non-null   float64
#  11  VRDeck        8505 non-null   float64
#  12  Name          8493 non-null   object
#  13  Transported   8693 non-null   bool
# dtypes: bool(1), float64(6), object(7)
# memory usage: 891.5+ KB

# %%
df.drop(columns=['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'VRDeck', 'Spa', 'Name','Cabin'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  8693 non-null   object
#  1   HomePlanet   8492 non-null   object
#  2   CryoSleep    8476 non-null   object
#  3   Destination  8511 non-null   object
#  4   VIP          8490 non-null   object
#  5   Transported  8693 non-null   bool
# dtypes: bool(1), object(5)
# memory usage: 348.2+ KB

# %%
df
# Out:
#      PassengerId HomePlanet CryoSleep    Destination    VIP  Transported
# 0        0001_01     Europa     False    TRAPPIST-1e  False        False
# 1        0002_01      Earth     False    TRAPPIST-1e  False         True
# 2        0003_01     Europa     False    TRAPPIST-1e   True        False
# 3        0003_02     Europa     False    TRAPPIST-1e  False        False
# 4        0004_01      Earth     False    TRAPPIST-1e  False         True
# ...          ...        ...       ...            ...    ...          ...
# 8688     9276_01     Europa     False    55 Cancri e   True        False
# 8689     9278_01      Earth      True  PSO J318.5-22  False        False
# 8690     9279_01      Earth     False    TRAPPIST-1e  False         True
# 8691     9280_01     Europa     False    55 Cancri e  False        False
# 8692     9280_02     Europa     False    TRAPPIST-1e  False         True
#
# [8693 rows x 6 columns]

# %%
df["HomePlanet"].fillna(value = df["HomePlanet"].mode()[0],inplace=True)
# Out:
# /var/folders/w0/j31vsdms32g0_2nr9v1sgt7h0000gp/T/ipykernel_1480/387642342.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["HomePlanet"].fillna(value = df["HomePlanet"].mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  8693 non-null   object
#  1   HomePlanet   8693 non-null   object
#  2   CryoSleep    8476 non-null   object
#  3   Destination  8511 non-null   object
#  4   VIP          8490 non-null   object
#  5   Transported  8693 non-null   bool
# dtypes: bool(1), object(5)
# memory usage: 348.2+ KB

# %%
df
# Out:
#      PassengerId HomePlanet CryoSleep    Destination    VIP  Transported
# 0        0001_01     Europa     False    TRAPPIST-1e  False        False
# 1        0002_01      Earth     False    TRAPPIST-1e  False         True
# 2        0003_01     Europa     False    TRAPPIST-1e   True        False
# 3        0003_02     Europa     False    TRAPPIST-1e  False        False
# 4        0004_01      Earth     False    TRAPPIST-1e  False         True
# ...          ...        ...       ...            ...    ...          ...
# 8688     9276_01     Europa     False    55 Cancri e   True        False
# 8689     9278_01      Earth      True  PSO J318.5-22  False        False
# 8690     9279_01      Earth     False    TRAPPIST-1e  False         True
# 8691     9280_01     Europa     False    55 Cancri e  False        False
# 8692     9280_02     Europa     False    TRAPPIST-1e  False         True
#
# [8693 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# HomePlanet       0
# CryoSleep      217
# Destination    182
# VIP            203
# Transported      0
# dtype: int64

# %%
df["CryoSleep"].fillna(value = df["CryoSleep"].mode()[0],inplace=True)
# Out:
# /var/folders/w0/j31vsdms32g0_2nr9v1sgt7h0000gp/T/ipykernel_1480/1203202225.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["CryoSleep"].fillna(value = df["CryoSleep"].mode()[0],inplace=True)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  8693 non-null   object
#  1   HomePlanet   8693 non-null   object
#  2   CryoSleep    8693 non-null   bool
#  3   Destination  8511 non-null   object
#  4   VIP          8490 non-null   object
#  5   Transported  8693 non-null   bool
# dtypes: bool(2), object(4)
# memory usage: 288.8+ KB

# %%
df["Destination"].fillna(value = df["Destination"].mode()[0],inplace=True)
df["VIP"].fillna(value = df["VIP"].mode()[0],inplace=True)
# Out:
# /var/folders/w0/j31vsdms32g0_2nr9v1sgt7h0000gp/T/ipykernel_1480/1828039422.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Destination"].fillna(value = df["Destination"].mode()[0],inplace=True)
# /var/folders/w0/j31vsdms32g0_2nr9v1sgt7h0000gp/T/ipykernel_1480/1828039422.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  8693 non-null   object
#  1   HomePlanet   8693 non-null   object
#  2   CryoSleep    8693 non-null   bool
#  3   Destination  8693 non-null   object
#  4   VIP          8693 non-null   bool
#  5   Transported  8693 non-null   bool
# dtypes: bool(3), object(3)
# memory usage: 229.3+ KB

# %%
df['CryoSleep'] = df['CryoSleep'].astype(int)
df['VIP'] = df['VIP'].astype(int)
df['Transported'] = df['Transported'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  8693 non-null   object
#  1   HomePlanet   8693 non-null   object
#  2   CryoSleep    8693 non-null   int64
#  3   Destination  8693 non-null   object
#  4   VIP          8693 non-null   int64
#  5   Transported  8693 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 407.6+ KB

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['HomePlanet'] = label_encoder.fit_transform(df['HomePlanet'])

df['Destination'] = label_encoder.fit_transform(df['Destination'])

df
# Out:
#      PassengerId  HomePlanet  CryoSleep  Destination  VIP  Transported
# 0        0001_01           1          0            2    0            0
# 1        0002_01           0          0            2    0            1
# 2        0003_01           1          0            2    1            0
# 3        0003_02           1          0            2    0            0
# 4        0004_01           0          0            2    0            1
# ...          ...         ...        ...          ...  ...          ...
# 8688     9276_01           1          0            0    1            0
# 8689     9278_01           0          1            1    0            0
# 8690     9279_01           0          0            2    0            1
# 8691     9280_01           1          0            0    0            0
# 8692     9280_02           1          0            2    0            1
#
# [8693 rows x 6 columns]

# %% [markdown]
# # Test file preprocessing

# %%
df2 = pd.read_csv('test.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4277 entries, 0 to 4276
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   4277 non-null   object
#  1   HomePlanet    4190 non-null   object
#  2   CryoSleep     4184 non-null   object
#  3   Cabin         4177 non-null   object
#  4   Destination   4185 non-null   object
#  5   Age           4186 non-null   float64
#  6   VIP           4184 non-null   object
#  7   RoomService   4195 non-null   float64
#  8   FoodCourt     4171 non-null   float64
#  9   ShoppingMall  4179 non-null   float64
#  10  Spa           4176 non-null   float64
#  11  VRDeck        4197 non-null   float64
#  12  Name          4183 non-null   object
# dtypes: float64(6), object(7)
# memory usage: 434.5+ KB

# %%
df2.drop(columns=['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'VRDeck', 'Spa', 'Name','Cabin'], inplace=True)

# %%
df2["HomePlanet"].fillna(value = df2["HomePlanet"].mode()[0],inplace=True)
df2["Destination"].fillna(value = df2["Destination"].mode()[0],inplace=True)
df2["VIP"].fillna(value = df2["VIP"].mode()[0],inplace=True)
df2["CryoSleep"].fillna(value = df2["CryoSleep"].mode()[0],inplace=True)
# Out:
# /var/folders/w0/j31vsdms32g0_2nr9v1sgt7h0000gp/T/ipykernel_1480/339196046.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["HomePlanet"].fillna(value = df2["HomePlanet"].mode()[0],inplace=True)
# /var/folders/w0/j31vsdms32g0_2nr9v1sgt7h0000gp/T/ipykernel_1480/339196046.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4277 entries, 0 to 4276
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  4277 non-null   object
#  1   HomePlanet   4277 non-null   object
#  2   CryoSleep    4277 non-null   bool
#  3   Destination  4277 non-null   object
#  4   VIP          4277 non-null   bool
# dtypes: bool(2), object(3)
# memory usage: 108.7+ KB

# %%
df2['CryoSleep'] = df2['CryoSleep'].astype(int)
df2['VIP'] = df2['VIP'].astype(int)

# %%
label_encoder = LabelEncoder()
df2['HomePlanet'] =label_encoder.fit_transform(df2['HomePlanet'])

df2['Destination'] = label_encoder.fit_transform(df2['Destination'])

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Training Model

# %%
target = df['Transported']
X = df.drop(columns= ['Transported'])

# %%
model = RandomForestClassifier()
model.fit(X,target)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # Evaluating

# %%
pred_test= model.predict(X)

# %% [markdown]
# # Saving Model

# %%
predicted = model.predict(df2)
submission = pd.DataFrame({
    'PassengerId': df2['PassengerId'], 
    'Transported': pd.Series(predicted).map({0: False, 1: True})
})
submission.to_csv('submission.csv', index=False)
